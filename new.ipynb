# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

from dotenv import load_dotenv
# import secret as secret


def fetch_data(api_url, params, no_of_records=None):
    """
    Fetch data from EIA API

    :param api_url: Provide the base API URL.
    :param params: Provide parameters for the data, e.g., your API key, frequency.
    :param no_of_records: Maximum number of records to fetch (default is None, meaning fetch all records).
    :return: A pandas DataFrame containing the fetched data.
    """
    params['offset'] = 500000
    complete_data = pd.DataFrame()
    total_records_fetched = 0  

    while True:
        response = requests.get(api_url, params=params)
        # response.raise_for_status()
        data = response.json()

        records = data['response']['data']

        if not records:
            break

        df = pd.DataFrame(records)
        complete_data = pd.concat([complete_data, df], ignore_index=True)
        total_records_fetched += len(records)
        params['offset'] += len(records)

        if no_of_records is  not None:
            if total_records_fetched>=no_of_records:
                return complete_data.iloc[:no_of_records]
        

    return complete_data



def mysql_connect(dataframe, table_name):
    """
    Insert DataFrame into MySQL.

    :param dataframe: DataFrame name
    :param table_name: Table name

    """
    mysql_connection_string = 'mysql+pymysql://root:root@localhost:3306/eia'
    engine = create_engine(mysql_connection_string)
 
    dataframe.to_sql(table_name, con=engine, if_exists='append', index=False)
    print(f"{dataframe} stored in mysql")

base_url = "https://api.eia.gov/v2/"


api1_url = f"{base_url}co2-emissions/co2-emissions-aggregates/data/"
api2_url = f"{base_url}electricity/rto/daily-fuel-type-data/data/"
api3_url = f"{base_url}international/data/"

# print(api1_url)
api3_params = {
    "frequency": "annual",
    "data[0]": "value",
    "facets[productId][]": [116, 33, 37],
    "facets[countryRegionId][]": "USA",
    "api_key": "ixxID9vFalaJnrWYcqNbAPMFRkmKIiC4OJlAGoae"

}
api1_params = {
    "frequency": "annual",
    "data[0]": "value",
    "api_key": "ixxID9vFalaJnrWYcqNbAPMFRkmKIiC4OJlAGoae"
}


api2_params = {
    "frequency": "daily",
    "data[0]": "value",
    "api_key": "ixxID9vFalaJnrWYcqNbAPMFRkmKIiC4OJlAGoae"
}

# print(api_key)
# df1 = fetch_data(api1_url, api1_params, no_of_records=5000)
df2 = fetch_data(api2_url, api2_params, no_of_records=50000)  
# df3 = fetch_data(api3_url, api3_params, no_of_records=5000)
data_api2=df2[['period','respondent-name','type-name','value','value-units']]
# df1 = df1[["period",'fuel-name','state-name','value','value-units']]
# print(df1)

# # mysql_connect(data_api1,"df1")
mysql_connect(data_api2,"df2")
# mysql_connect(data_api3,"df3")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 91
#      83 api2_params = {
#      84     "frequency": "daily",
#      85     "data[0]": "value",
#      86     "api_key": "ixxID9vFalaJnrWYcqNbAPMFRkmKIiC4OJlAGoae"
#      87 }
#      89 # print(api_key)
#      90 # df1 = fetch_data(api1_url, api1_params, no_of_records=5000)
# ---> 91 df2 = fetch_data(api2_url, api2_params, no_of_records=50000)
#      92 # df3 = fetch_data(api3_url, api3_params, no_of_records=5000)
#      93 data_api2=df2[['period','respondent-name','type-name','value','value-units']]
#
# Cell In[1], line 23, in fetch_data(api_url, params, no_of_records)
#      20 total_records_fetched = 0
#      22 while True:
# ---> 23     response = requests.get(api_url, params=params)
#      24     # response.raise_for_status()
#      25     data = response.json()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df3 = fetch_data(api3_url, api3_params, no_of_records=5001)
df1 = fetch_data(api1_url, api1_params, no_of_records=5001)

# %%
print(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df3)
#
# NameError: name 'df3' is not defined

# %%
emission_factors = {
    'Coal': 0.91, 
    'Natural Gas': 0.45,  
    'Oil': 0.77,
    'Renewables':0  
}
print(emission_factors)
# Out:
# {'Coal': 0.91, 'Natural Gas': 0.45, 'Oil': 0.77, 'Renewables': 0}

# %%
data_api2['value'] = pd.to_numeric(data_api2['value'], errors='coerce')
data_api2.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_api2['value'] = pd.to_numeric(data_api2['value'], errors='coerce')
#       2 data_api2.info()
#
# NameError: name 'data_api2' is not defined

# %%
data_api_new = data_api2[data_api2['type-name'].isin(emission_factors.keys())] 


data_api_new['emission_factors'] = data_api_new['type-name'].map(emission_factors)


data_api_new['co2_emissions(tons)'] = data_api_new['value'] * data_api_new['emission_factors']

data_api_new.head(20)
# Out:
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_18884\2583005485.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_api_new['emission_factors'] = data_api_new['type-name'].map(emission_factors)
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_18884\2583005485.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_api_new['co2_emissions(tons)'] = data_api_new['value'] * data_api_new['emission_factors']
#         period respondent                        respondent-name fueltype  \
# 0   2024-09-30       AECI  Associated Electric Cooperative, Inc.      COL
# 1   2024-09-30       AECI  Associated Electric Cooperative, Inc.      COL
# 2   2024-09-30       AECI  Associated Electric Cooperative, Inc.       NG
# 3   2024-09-30       AECI  Associated Electric Cooperative, Inc.       NG
# 6   2024-09-30        AVA                     Avista Corporation       NG
# 7   2024-09-30        AVA                     Avista Corporation       NG
# 8   2024-09-30        AVA                     Avista Corporation       NG
# 9   2024-09-30        AVA                     Avista Corporation       NG
# 10  2024-09-30        AVA                     Avista Corporation       NG
# 31  2024-09-30       AVRN               Avangrid Renewables, LLC       NG
# 32  2024-09-30       AVRN               Avangrid Renewables, LLC       NG
# 33  2024-09-30       AVRN               Avangrid Renewables, LLC       NG
# 34  2024-09-30       AVRN               Avangrid Renewables, LLC       NG
# 35  2024-09-30       AVRN               Avangrid Renewables, LLC       NG
# 51  2024-09-30       AZPS         Arizona Public Service Company      COL
# 52  2024-09-30       AZPS         Arizona Public Service Company      COL
# 53  2024-09-30       AZPS         Arizona Public Service Company      COL
# 54  2024-09-30       AZPS         Arizona Public Service Company      COL
# 55  2024-09-30       AZPS         Arizona Public Service Company      COL
# 56  2024-09-30       AZPS         Arizona Public Service Company       NG
#
#       type-name  timezone timezone-description  value    value-units  \
# 0          Coal   Central              Central  35188  megawatthours
# 1          Coal   Eastern              Eastern  35188  megawatthours
# 2   Natural Gas   Central              Central  13119  megawatthours
# 3   Natural Gas   Eastern              Eastern  13119  megawatthours
# 6   Natural Gas   Arizona              Arizona   8793  megawatthours
# 7   Natural Gas   Central              Central   8793  megawatthours
# 8   Natural Gas   Eastern              Eastern   8793  megawatthours
# 9   Natural Gas  Mountain             Mountain   8793  megawatthours
# 10  Natural Gas   Pacific              Pacific   8793  megawatthours
# 31  Natural Gas   Arizona              Arizona  10456  megawatthours
# 32  Natural Gas   Central              Central  10456  megawatthours
# 33  Natural Gas   Eastern              Eastern  10456  megawatthours
# 34  Natural Gas  Mountain             Mountain  10456  megawatthours
# 35  Natural Gas   Pacific              Pacific  10456  megawatthours
# 51         Coal   Arizona              Arizona  28152  megawatthours
# 52         Coal   Central              Central  28152  megawatthours
# 53         Coal   Eastern              Eastern  28152  megawatthours
# 54         Coal  Mountain             Mountain  28152  megawatthours
# 55         Coal   Pacific              Pacific  28152  megawatthours
# 56  Natural Gas   Arizona              Arizona  28145  megawatthours
#
#     emission_factors  co2_emissions(tons)
# 0               0.91             32021.08
# 1               0.91             32021.08
# 2               0.45              5903.55
# 3               0.45              5903.55
# 6               0.45              3956.85
# 7               0.45              3956.85
# 8               0.45              3956.85
# 9               0.45              3956.85
# 10              0.45              3956.85
# 31              0.45              4705.20
# 32              0.45              4705.20
# 33              0.45              4705.20
# 34              0.45              4705.20
# 35              0.45              4705.20
# 51              0.91             25618.32
# 52              0.91             25618.32
# 53              0.91             25618.32
# 54              0.91             25618.32
# 55              0.91             25618.32
# 56              0.45             12665.25

# %%
df_aggregated = data_api_new.groupby(['period','type-name'], as_index=False)['co2_emissions(tons)'].sum()

# %%
df_aggregated.head(20)
# Out:
#        period    type-name  co2_emissions(tons)
# 0  2024-09-27         Coal           2300873.12
# 1  2024-09-27  Natural Gas           1757594.25
# 2  2024-09-28         Coal          24096057.44
# 3  2024-09-28  Natural Gas          29271829.05
# 4  2024-09-29         Coal          24189866.61
# 5  2024-09-29  Natural Gas          30059275.50
# 6  2024-09-30         Coal          10118863.30
# 7  2024-09-30  Natural Gas          11015640.00

# %%
df_aggregated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   period               8 non-null      object
#  1   type-name            8 non-null      object
#  2   co2_emissions(tons)  8 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 324.0+ bytes

# %%
data_api_new['period'] = pd.to_datetime(data_api_new['period'])

# Extract the year and create a new column
data_api_new['year'] = data_api_new['period'].dt.year
df_aggregated = data_api_new.groupby(['year', 'type-name'], as_index=False)['co2_emissions(tons)'].sum()

print(df_aggregated)
# Out:
#    year    type-name  co2_emissions(tons)
# 0  2024         Coal          60705660.47
# 1  2024  Natural Gas          72104338.80
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_18884\3325002521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_api_new['period'] = pd.to_datetime(data_api_new['period'])
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_18884\3325002521.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_api_new['year'] = data_api_new['period'].dt.year

# %%
new_data = data_api1

new_data.head()
# Out:
#   period sectorId                              sector-name fuelId  \
# 0   1983       EC  Electric Power carbon dioxide emissions     PE
# 1   1983       EC  Electric Power carbon dioxide emissions     NG
# 2   1983       EC  Electric Power carbon dioxide emissions     TO
# 3   1983       IC      Industrial carbon dioxide emissions     CO
# 4   1983       IC      Industrial carbon dioxide emissions     PE
#
#      fuel-name stateId   state-name     value                 value-units
# 0    Petroleum      CT  Connecticut  9.314567  million metric tons of CO2
# 1  Natural Gas      CT  Connecticut         0  million metric tons of CO2
# 2    All Fuels      CT  Connecticut  9.314567  million metric tons of CO2
# 3         Coal      CT  Connecticut   .018643  million metric tons of CO2
# 4    Petroleum      CT  Connecticut  1.595678  million metric tons of CO2

# %%
df2.head()
# Out:
#        period                        respondent-name    type-name  value  \
# 0  2024-10-03  Associated Electric Cooperative, Inc.         Coal  32460
# 1  2024-10-03  Associated Electric Cooperative, Inc.         Coal  32460
# 2  2024-10-03  Associated Electric Cooperative, Inc.  Natural Gas  11132
# 3  2024-10-03  Associated Electric Cooperative, Inc.  Natural Gas  11132
# 4  2024-10-03  Associated Electric Cooperative, Inc.         Wind   9642
#
#      value-units  Year
# 0  megawatthours  2024
# 1  megawatthours  2024
# 2  megawatthours  2024
# 3  megawatthours  2024
# 4  megawatthours  2024

# %%
df2['Year'] = pd.to_datetime(df2['period']).dt.year
df2['value'] = pd.to_numeric(df2['value'])
emission_factors = {
    'coal': 1.03, 
    'Natural Gas': 0.42, 
    'Petroleum':0.93
}
renewables = ['Wind', 'Solar', 'Hydro']  
non_renewables = ['Coal', 'Natural Gas', 'Petroleum','Nuclear']

renewable_generation = df2[df2['type-name'].isin(renewables)]['value'].sum()

non_renewable = df2[df2['type-name'].isin(non_renewables)]
non_renewable['emission_factor'] = non_renewable['type-name'].map(emission_factors)


weighted_avg_emission_factor = (non_renewable['value'] * non_renewable['emission_factor']).sum() / non_renewable['value'].sum()


co2_reduction = renewable_generation * weighted_avg_emission_factor

print(f"renewabl generation:  {renewable_generation}")
print(f"weighted average emission factor : {weighted_avg_emission_factor}")
print(f"CO2 Emissions Avoided: {co2_reduction} ")
# Out:
# renewabl generation:  82102915
# weighted average emission factor : 0.23896815046261025
# CO2 Emissions Avoided: 19619981.7451389
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_10296\1269835771.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_renewable['emission_factor'] = non_renewable['type-name'].map(emission_factors)

# %%
# # df2.head()
# df2.Year.unique()
# non_renewable = df2[df2['fueltype'].isin(non_renewables)]
# non_renewable['emission_factor'] = non_renewable['fueltype'].map(emission_factors)
# Out:
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_20272\926887166.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_renewable['emission_factor'] = non_renewable['fueltype'].map(emission_factors)

# %%
non_renewable["value"].sum()
# Out:
# np.int64(1345707484)

# %%
weighted_avg_emission_factor = (non_renewable['value'] * non_renewable['emission_factor']).sum() / non_renewable['value'].sum()


co2_reduction = renewable_generation * weighted_avg_emission_factor

print(f"renewabl generation:  {renewable_generation}")
print(f"weighted average emission factor : {weighted_avg_emission_factor}")
print(f"CO2 Emissions Avoided: {co2_reduction} ")
# Out:
# renewabl generation:  858808339
# weighted average emission factor : 0.21295470815177886
# CO2 Emissions Avoided: 182887279.19005898

# %%
df2.head()
# Out:
#        period                                    respondent-name type-name  \
# 0  2024-01-20  Western Area Power Administration - Upper Grea...     Hydro
# 1  2024-01-20  Western Area Power Administration - Upper Grea...     Hydro
# 2  2024-01-20                          NaturEner Wind Watch, LLC      Wind
# 3  2024-01-20                          NaturEner Wind Watch, LLC      Wind
# 4  2024-01-20                          NaturEner Wind Watch, LLC      Wind
#
#    value    value-units  Year
# 0   1613  megawatthours  2024
# 1   1603  megawatthours  2024
# 2   2439  megawatthours  2024
# 3   2474  megawatthours  2024
# 4   2511  megawatthours  2024

# %%
yearly_co2_reduction = []

for year, group in df2.groupby('Year'):
    renewable_generation = group[group['type-name'].isin(renewables)]['value'].sum()
    

    non_renewable_gen = group[group['type-name'].isin(non_renewables)]
    
    weighted_avg_emission_factor = (non_renewable_gen['value'] * non_renewable_gen['type-name'].map(emission_factors)).sum() / non_renewable_gen['value'].sum()
     

   
    co2_reduction = renewable_generation * weighted_avg_emission_factor
    

    yearly_co2_reduction.append({
        'Year': year,
        'Total Renewable Generation': renewable_generation,
        'Weighted Average Emission Factor': weighted_avg_emission_factor,
        'CO2 Emissions Avoided': co2_reduction
    })

# %%
yearly_co2_df = pd.DataFrame(yearly_co2_reduction)


print(yearly_co2_df)
# Out:
#    Year  Total Renewable Generation  Weighted Average Emission Factor  \
# 0  2024                    82102915                          0.238968
#
#    CO2 Emissions Avoided
# 0           1.961998e+07

# %%
print(df3.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_capacity = df3[(df3['activityName'] == 'Capacity')]

print(df_capacity)
# Out:
#     period productId       productName activityId activityName  \
# 3     2008        33  Hydroelectricity          7     Capacity
# 21    2011       116             Solar          7     Capacity
# 25    2016        33  Hydroelectricity          7     Capacity
# 26    2009       116             Solar          7     Capacity
# 27    1985        37              Wind          7     Capacity
# ..     ...       ...               ...        ...          ...
# 593   1996        33  Hydroelectricity          7     Capacity
# 600   2005        37              Wind          7     Capacity
# 602   2010        37              Wind          7     Capacity
# 605   2021        37              Wind          7     Capacity
# 609   1985        33  Hydroelectricity          7     Capacity
#
#     countryRegionId countryRegionName countryRegionTypeId  \
# 3               USA     United States                   c
# 21              USA     United States                   c
# 25              USA     United States                   c
# 26              USA     United States                   c
# 27              USA     United States                   c
# ..              ...               ...                 ...
# 593             USA     United States                   c
# 600             USA     United States                   c
# 602             USA     United States                   c
# 605             USA     United States                   c
# 609             USA     United States                   c
#
#     countryRegionTypeName dataFlagId  \
# 3                 Country       None
# 21                Country       None
# 25                Country       None
# 26                Country       None
# 27                Country          5
# ..                    ...        ...
# 593               Country       None
# 600               Country       None
# 602               Country       None
# 605               Country       None
# 609               Country       None
#
#                                    dataFlagDescription           unitName  \
# 3                                                 None  million kilowatts
# 21                                                None  million kilowatts
# 25                                                None  million kilowatts
# 26                                                None  million kilowatts
# 27   A value exists, but rounds to zero; non-rounde...  million kilowatts
# ..                                                 ...                ...
# 593                                               None  million kilowatts
# 600                                               None  million kilowatts
# 602                                               None  million kilowatts
# 605                                               None  million kilowatts
# 609                                               None  million kilowatts
#
#         value unit
# 3       77.93   MK
# 21     1.5235   MK
# 25    79.9129   MK
# 26      .6185   MK
# 27    .017501   MK
# ..        ...  ...
# 593  76.43742   MK
# 600   8.70641   MK
# 602   39.1345   MK
# 605  132.7534   MK
# 609      88.9   MK
#
# [110 rows x 14 columns]

# %%
df_capacity['value'] = pd.to_numeric(df_capacity['value'], errors='coerce')
df_capacity = df_capacity.sort_values(by='period')
df_capacity['capacity_increase'] = df_capacity['value'].diff()  
df_capacity['capacity_increase'].fillna(0, inplace=True)
print(df_capacity[['period','productName', 'activityName','value', 'capacity_increase']])
# Out:
#     period       productName activityName       value  capacity_increase
# 184   1980  Hydroelectricity     Capacity   81.700000           0.000000
# 453   1981  Hydroelectricity     Capacity   82.400000           0.700000
# 95    1981              Wind     Capacity    0.000360         -82.399640
# 160   1982              Wind     Capacity    0.005555           0.005195
# 247   1982  Hydroelectricity     Capacity   83.000000          82.994445
# ..     ...               ...          ...         ...                ...
# 559   2022  Hydroelectricity     Capacity   80.067600         -52.685800
# 56    2022              Wind     Capacity  141.402200          61.334600
# 477   2022             Solar     Capacity  112.689500         -28.712700
# 479   2023              Wind     Capacity  147.639800          34.950300
# 71    2023  Hydroelectricity     Capacity   80.089700         -67.550100
#
# [110 rows x 5 columns]
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_16592\991904490.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_capacity['capacity_increase'].fillna(0, inplace=True)

# %%
df_capacity['value'] = pd.to_numeric(df_capacity['value'], errors='coerce')
df_capacity = df_capacity.sort_values(by=['productName', 'period'])

df_capacity['capacity_increase'] = df_capacity.groupby('productName')['value'].diff()
df_capacity['capacity_increase'].fillna(0, inplace=True)

df_capacity=df_capacity[['period', 'productName', 'activityName', 'value', 'capacity_increase']]
# Out:
# C:\Users\JayShah\AppData\Local\Temp\ipykernel_10296\3352690794.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_capacity['capacity_increase'].fillna(0, inplace=True)

# %%
df_capacity.head(30)
# Out:
#     period       productName activityName      value  capacity_increase
# 289   1980  Hydroelectricity     Capacity  81.700000           0.000000
# 198   1981  Hydroelectricity     Capacity  82.400000           0.700000
# 458   1982  Hydroelectricity     Capacity  83.000000           0.600000
# 311   1983  Hydroelectricity     Capacity  83.900000           0.900000
# 571   1984  Hydroelectricity     Capacity  85.300000           1.400000
# 609   1985  Hydroelectricity     Capacity  88.900000           3.600000
# 259   1986  Hydroelectricity     Capacity  89.300000           0.400000
# 98    1987  Hydroelectricity     Capacity  89.700000           0.400000
# 141   1988  Hydroelectricity     Capacity  90.300000           0.600000
# 340   1989  Hydroelectricity     Capacity  74.110934         -16.189066
# 43    1990  Hydroelectricity     Capacity  73.923050          -0.187884
# 549   1991  Hydroelectricity     Capacity  76.036310           2.113260
# 199   1992  Hydroelectricity     Capacity  74.772700          -1.263610
# 490   1993  Hydroelectricity     Capacity  77.410420           2.637720
# 49    1994  Hydroelectricity     Capacity  78.040930           0.630510
# 312   1995  Hydroelectricity     Capacity  78.561730           0.520800
# 593   1996  Hydroelectricity     Capacity  76.437420          -2.124310
# 447   1997  Hydroelectricity     Capacity  79.414580           2.977160
# 210   1998  Hydroelectricity     Capacity  79.150650          -0.263930
# 372   1999  Hydroelectricity     Capacity  79.393070           0.242420
# 52    2000  Hydroelectricity     Capacity  79.359079          -0.033991
# 364   2001  Hydroelectricity     Capacity  78.915780          -0.443299
# 131   2002  Hydroelectricity     Capacity  79.355900           0.440120
# 166   2003  Hydroelectricity     Capacity  78.693910          -0.661990
# 44    2004  Hydroelectricity     Capacity  77.640500          -1.053410
# 567   2005  Hydroelectricity     Capacity  77.540870          -0.099630
# 320   2006  Hydroelectricity     Capacity  77.820960           0.280090
# 483   2007  Hydroelectricity     Capacity  77.885000           0.064040
# 3     2008  Hydroelectricity     Capacity  77.930000           0.045000
# 290   2009  Hydroelectricity     Capacity  78.518000           0.588000
